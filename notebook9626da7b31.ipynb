# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/top-1000-imdb-movies/imdb_top_1000.csv

# %%
import pandas as pd

# %%
df = pd.read_csv('../input/top-1000-imdb-movies/imdb_top_1000.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    1000 non-null   object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          1000 non-null   int64
# dtypes: float64(2), int64(2), object(12)
# memory usage: 125.1+ KB

# %%
df = df[['Series_Title', 'Genre', 'IMDB_Rating', 'Star1', 'Star2', 'Star3', 'Star4', 'Director', 'Gross']]

# %%
df.head(3)
# Out:
#                Series_Title   Genre  IMDB_Rating           Star1  \
# 0  The Shawshank Redemption   Drama          9.3     Tim Robbins
# 1             The Godfather   Crime          9.2   Marlon Brando
# 2           The Dark Knight  Action          9.0  Christian Bale
#
#             Star2          Star3           Star4              Director  \
# 0  Morgan Freeman     Bob Gunton  William Sadler        Frank Darabont
# 1       Al Pacino     James Caan    Diane Keaton  Francis Ford Coppola
# 2    Heath Ledger  Aaron Eckhart   Michael Caine     Christopher Nolan
#
#        Gross
# 0   28341469
# 1  134966411
# 2  534858444

# %%
df['Genre'].value_counts()
# Out:
# Drama        289
# Action       172
# Comedy       155
# Crime        107
# Biography     88
# Animation     82
# Adventure     72
# Mystery       12
# Horror        11
# Western        4
# Film-Noir      3
# Fantasy        2
# Family         2
# Thriller       1
# Name: Genre, dtype: int64

# %%
df['Star1'].value_counts().head(10)
# Out:
# Tom Hanks            12
# Robert De Niro       11
# Al Pacino            10
# Clint Eastwood       10
# Humphrey Bogart       9
# Leonardo DiCaprio     9
# Johnny Depp           8
# Christian Bale        8
# James Stewart         8
# Denzel Washington     7
# Name: Star1, dtype: int64

# %%
df['Star1'].value_counts().tail(10)
# Out:
# Richard Farnsworth    1
# Björk                 1
# Ömer Faruk Sorak      1
# Tae-Hyun Cha          1
# Alan Mak              1
# Preity Zinta          1
# Javier Bardem         1
# Ki-duk Kim            1
# Vladimir Garin        1
# Robert Donat          1
# Name: Star1, dtype: int64

# %%
fil = df['Star1'] == 'Tom Hanks'
df[fil]
df.loc[fil, 'Series_Title']
# Out:
# 11            Forrest Gump
# 24     Saving Private Ryan
# 25          The Green Mile
# 101              Toy Story
# 151            Toy Story 3
# 596            Toy Story 4
# 604       Captain Phillips
# 647              Cast Away
# 791      Road to Perdition
# 818           Philadelphia
# 890        Bridge of Spies
# 966              Apollo 13
# Name: Series_Title, dtype: object

# %%
df.isin(['Tom Hanks'])
df.isin(['Tom Hanks']).any()
df[df.isin(['Tom Hanks']).any(1)]
df.loc[df.isin(['Tom Hanks']).any(1), 'Genre']
# Out:
# 11         Drama
# 24         Drama
# 25         Crime
# 101    Animation
# 151    Animation
# 243    Biography
# 516    Animation
# 596    Animation
# 604    Adventure
# 647    Adventure
# 791        Crime
# 818        Drama
# 890        Drama
# 966    Adventure
# Name: Genre, dtype: object

# %%
df[(df['Star1'] == 'Tom Hanks') | (df['Star2'] == 'Tom Hanks') | (df['Star3'] == 'Tom Hanks')]
# Out:
#             Series_Title      Genre  IMDB_Rating              Star1  \
# 11          Forrest Gump      Drama          8.8          Tom Hanks
# 24   Saving Private Ryan      Drama          8.6          Tom Hanks
# 25        The Green Mile      Crime          8.6          Tom Hanks
# 101            Toy Story  Animation          8.3          Tom Hanks
# 151          Toy Story 3  Animation          8.2          Tom Hanks
# 243  Catch Me If You Can  Biography          8.1  Leonardo DiCaprio
# 516          Toy Story 2  Animation          7.9        Ash Brannon
# 596          Toy Story 4  Animation          7.8          Tom Hanks
# 604     Captain Phillips  Adventure          7.8          Tom Hanks
# 647            Cast Away  Adventure          7.8          Tom Hanks
# 791    Road to Perdition      Crime          7.7          Tom Hanks
# 818         Philadelphia      Drama          7.7          Tom Hanks
# 890      Bridge of Spies      Drama          7.6          Tom Hanks
# 966            Apollo 13  Adventure          7.6          Tom Hanks
#
#                      Star2               Star3             Star4  \
# 11            Robin Wright         Gary Sinise       Sally Field
# 24              Matt Damon        Tom Sizemore      Edward Burns
# 25   Michael Clarke Duncan         David Morse       Bonnie Hunt
# 101              Tim Allen         Don Rickles        Jim Varney
# 151              Tim Allen         Joan Cusack        Ned Beatty
# 243              Tom Hanks  Christopher Walken      Martin Sheen
# 516            Lee Unkrich           Tom Hanks         Tim Allen
# 596              Tim Allen         Annie Potts         Tony Hale
# 604           Barkhad Abdi  Barkhad Abdirahman  Catherine Keener
# 647             Helen Hunt        Paul Sanchez        Lari White
# 791         Tyler Hoechlin           Rob Maxey        Liam Aiken
# 818      Denzel Washington     Roberta Maxwell       Buzz Kilman
# 890           Mark Rylance           Alan Alda          Amy Ryan
# 966            Bill Paxton         Kevin Bacon       Gary Sinise
#
#              Director      Gross
# 11    Robert Zemeckis  330252182
# 24   Steven Spielberg  216540909
# 25     Frank Darabont  136801374
# 101     John Lasseter  191796233
# 151       Lee Unkrich  415004880
# 243  Steven Spielberg  164615351
# 516     John Lasseter  245852179
# 596       Josh Cooley  434038008
# 604   Paul Greengrass  107100855
# 647   Robert Zemeckis  233632142
# 791        Sam Mendes  104454762
# 818    Jonathan Demme   77324422
# 890  Steven Spielberg   72313754
# 966        Ron Howard  173837933

# %%
df[df.isin(['Tom Hanks', 'Denzel Washington']).any(1)]
# Out:
#             Series_Title      Genre  IMDB_Rating              Star1  \
# 11          Forrest Gump      Drama          8.8          Tom Hanks
# 24   Saving Private Ryan      Drama          8.6          Tom Hanks
# 25        The Green Mile      Crime          8.6          Tom Hanks
# 101            Toy Story  Animation          8.3          Tom Hanks
# 151          Toy Story 3  Animation          8.2          Tom Hanks
# 243  Catch Me If You Can  Biography          8.1  Leonardo DiCaprio
# 516          Toy Story 2  Animation          7.9        Ash Brannon
# 596          Toy Story 4  Animation          7.8          Tom Hanks
# 604     Captain Phillips  Adventure          7.8          Tom Hanks
# 622    American Gangster  Biography          7.8  Denzel Washington
# 644  Remember the Titans  Biography          7.8  Denzel Washington
# 647            Cast Away  Adventure          7.8          Tom Hanks
# 673                Glory  Biography          7.8  Matthew Broderick
# 782          Man on Fire     Action          7.7  Denzel Washington
# 791    Road to Perdition      Crime          7.7          Tom Hanks
# 802         Training Day      Crime          7.7  Denzel Washington
# 818         Philadelphia      Drama          7.7          Tom Hanks
# 820            Malcolm X  Biography          7.7  Denzel Washington
# 890      Bridge of Spies      Drama          7.6          Tom Hanks
# 921           Inside Man      Crime          7.6  Denzel Washington
# 952        The Hurricane  Biography          7.6  Denzel Washington
# 966            Apollo 13  Adventure          7.6          Tom Hanks
#
#                      Star2               Star3                Star4  \
# 11            Robin Wright         Gary Sinise          Sally Field
# 24              Matt Damon        Tom Sizemore         Edward Burns
# 25   Michael Clarke Duncan         David Morse          Bonnie Hunt
# 101              Tim Allen         Don Rickles           Jim Varney
# 151              Tim Allen         Joan Cusack           Ned Beatty
# 243              Tom Hanks  Christopher Walken         Martin Sheen
# 516            Lee Unkrich           Tom Hanks            Tim Allen
# 596              Tim Allen         Annie Potts            Tony Hale
# 604           Barkhad Abdi  Barkhad Abdirahman     Catherine Keener
# 622          Russell Crowe    Chiwetel Ejiofor          Josh Brolin
# 644            Will Patton         Wood Harris           Ryan Hurst
# 647             Helen Hunt        Paul Sanchez           Lari White
# 673      Denzel Washington          Cary Elwes       Morgan Freeman
# 782     Christopher Walken      Dakota Fanning       Radha Mitchell
# 791         Tyler Hoechlin           Rob Maxey           Liam Aiken
# 802            Ethan Hawke         Scott Glenn         Tom Berenger
# 818      Denzel Washington     Roberta Maxwell          Buzz Kilman
# 820         Angela Bassett        Delroy Lindo            Spike Lee
# 890           Mark Rylance           Alan Alda             Amy Ryan
# 921             Clive Owen        Jodie Foster  Christopher Plummer
# 952      Vicellous Shannon  Deborah Kara Unger       Liev Schreiber
# 966            Bill Paxton         Kevin Bacon          Gary Sinise
#
#              Director      Gross
# 11    Robert Zemeckis  330252182
# 24   Steven Spielberg  216540909
# 25     Frank Darabont  136801374
# 101     John Lasseter  191796233
# 151       Lee Unkrich  415004880
# 243  Steven Spielberg  164615351
# 516     John Lasseter  245852179
# 596       Josh Cooley  434038008
# 604   Paul Greengrass  107100855
# 622      Ridley Scott  130164645
# 644        Boaz Yakin  115654751
# 647   Robert Zemeckis  233632142
# 673      Edward Zwick   26830000
# 782        Tony Scott   77911774
# 791        Sam Mendes  104454762
# 802     Antoine Fuqua   76631907
# 818    Jonathan Demme   77324422
# 820         Spike Lee   48169908
# 890  Steven Spielberg   72313754
# 921         Spike Lee   88513495
# 952    Norman Jewison   50668906
# 966        Ron Howard  173837933

# %%
df.head()
# Out:
#                Series_Title   Genre  IMDB_Rating           Star1  \
# 0  The Shawshank Redemption   Drama          9.3     Tim Robbins
# 1             The Godfather   Crime          9.2   Marlon Brando
# 2           The Dark Knight  Action          9.0  Christian Bale
# 3    The Godfather: Part II   Crime          9.0       Al Pacino
# 4              12 Angry Men   Crime          9.0     Henry Fonda
#
#             Star2          Star3           Star4              Director  \
# 0  Morgan Freeman     Bob Gunton  William Sadler        Frank Darabont
# 1       Al Pacino     James Caan    Diane Keaton  Francis Ford Coppola
# 2    Heath Ledger  Aaron Eckhart   Michael Caine     Christopher Nolan
# 3  Robert De Niro  Robert Duvall    Diane Keaton  Francis Ford Coppola
# 4     Lee J. Cobb  Martin Balsam    John Fiedler          Sidney Lumet
#
#        Gross
# 0   28341469
# 1  134966411
# 2  534858444
# 3   57300000
# 4    4360000

# %%
df.dtypes
# Out:
# Series_Title     object
# Genre            object
# IMDB_Rating     float64
# Star1            object
# Star2            object
# Star3            object
# Star4            object
# Director         object
# Gross             int64
# dtype: object

# %%
df.groupby(['Genre']).mean().sort_values('Gross')
# Out:
#            IMDB_Rating         Gross
# Genre
# Film-Noir     7.966667  9.647853e+05
# Fantasy       8.000000  5.269970e+06
# Western       8.350000  1.455538e+07
# Thriller      7.800000  1.755074e+07
# Mystery       7.975000  2.642347e+07
# Comedy        7.901290  2.983143e+07
# Crime         8.016822  3.244320e+07
# Drama         7.957439  3.838095e+07
# Biography     7.938636  6.047271e+07
# Horror        7.909091  6.690104e+07
# Adventure     7.937500  8.286716e+07
# Animation     7.930488  1.146530e+08
# Action        7.949419  1.220545e+08
# Family        7.800000  2.195553e+08

# %%
genre = df.groupby(['Genre'])
genre.get_group('Action')
# Out:
#                                           Series_Title   Genre  IMDB_Rating  \
# 2                                      The Dark Knight  Action          9.0
# 5        The Lord of the Rings: The Return of the King  Action          8.9
# 8                                            Inception  Action          8.8
# 10   The Lord of the Rings: The Fellowship of the Ring  Action          8.8
# 13               The Lord of the Rings: The Two Towers  Action          8.7
# ..                                                 ...     ...          ...
# 968                                       Falling Down  Action          7.6
# 979                                      Lethal Weapon  Action          7.6
# 982                                          Mad Max 2  Action          7.6
# 983                                       The Warriors  Action          7.6
# 985                               Escape from Alcatraz  Action          7.6
#
#                  Star1                 Star2            Star3           Star4  \
# 2       Christian Bale          Heath Ledger    Aaron Eckhart   Michael Caine
# 5          Elijah Wood       Viggo Mortensen     Ian McKellen   Orlando Bloom
# 8    Leonardo DiCaprio  Joseph Gordon-Levitt      Elliot Page    Ken Watanabe
# 10         Elijah Wood          Ian McKellen    Orlando Bloom       Sean Bean
# 13         Elijah Wood          Ian McKellen  Viggo Mortensen   Orlando Bloom
# ..                 ...                   ...              ...             ...
# 968    Michael Douglas         Robert Duvall  Barbara Hershey  Rachel Ticotin
# 979         Mel Gibson          Danny Glover       Gary Busey   Mitchell Ryan
# 982         Mel Gibson          Bruce Spence  Michael Preston      Max Phipps
# 983       Michael Beck           James Remar    Dorsey Wright     Brian Tyler
# 985     Clint Eastwood      Patrick McGoohan  Roberts Blossom    Jack Thibeau
#
#               Director      Gross
# 2    Christopher Nolan  534858444
# 5        Peter Jackson  377845905
# 8    Christopher Nolan  292576195
# 10       Peter Jackson  315544750
# 13       Peter Jackson  342551365
# ..                 ...        ...
# 968    Joel Schumacher   40903593
# 979     Richard Donner   65207127
# 982      George Miller   12465371
# 983        Walter Hill   22490039
# 985         Don Siegel   43000000
#
# [172 rows x 9 columns]

# %%
genre['Star1'].value_counts()
# Out:
# Genre     Star1
# Action    Harrison Ford            5
#           Christian Bale           4
#           Joe Russo                4
#           Tom Cruise               4
#           Arnold Schwarzenegger    3
#                                   ..
# Mystery   Rufus Sewell             1
#           Vidya Balan              1
# Thriller  Audrey Hepburn           1
# Western   Clint Eastwood           3
#           Henry Fonda              1
# Name: Star1, Length: 829, dtype: int64

# %%
genre['Star1'].value_counts().loc['Drama']
# Out:
# Star1
# Shah Rukh Khan      5
# Ethan Hawke         4
# Tom Hanks           4
# Clint Eastwood      3
# Dustin Hoffman      3
#                    ..
# Will Smith          1
# William Holden      1
# Yalitza Aparicio    1
# Zain Al Rafeea      1
# Çetin Tekindor      1
# Name: Star1, Length: 250, dtype: int64
